# %%
import os
from tqdm.autonotebook import tqdm, trange

import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler

import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time

from sklearn.model_selection import train_test_split
from pathlib import Path
from torch.utils.data import DataLoader

from torch.utils.data import Dataset
from sklearn.preprocessing import LabelEncoder
import pickle
from PIL import Image
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_22572\2258379951.py:2: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange

# %%
# !pip install wandb
# Out:
# Requirement already satisfied: wandb in d:\conda\envs\torch_1_9\lib\site-packages (0.13.4)
# Requirement already satisfied: protobuf!=4.0.*,!=4.21.0,<5,>=3.12.0 in d:\conda\envs\torch_1_9\lib\site-packages (from wandb) (3.19.4)
# Requirement already satisfied: promise<3,>=2.0 in d:\conda\envs\torch_1_9\lib\site-packages (from wandb) (2.3)
# Requirement already satisfied: shortuuid>=0.5.0 in d:\conda\envs\torch_1_9\lib\site-packages (from wandb) (1.0.9)
# Requirement already satisfied: sentry-sdk>=1.0.0 in d:\conda\envs\torch_1_9\lib\site-packages (from wandb) (1.9.10)
# Requirement already satisfied: PyYAML in d:\conda\envs\torch_1_9\lib\site-packages (from wandb) (6.0)
# Requirement already satisfied: pathtools in d:\conda\envs\torch_1_9\lib\site-packages (from wandb) (0.1.2)
# Requirement already satisfied: setuptools in d:\conda\envs\torch_1_9\lib\site-packages (from wandb) (61.2.0)
# Requirement already satisfied: psutil>=5.0.0 in d:\conda\envs\torch_1_9\lib\site-packages (from wandb) (5.9.1)
# Requirement already satisfied: six>=1.13.0 in d:\conda\envs\torch_1_9\lib\site-packages (from wandb) (1.16.0)
# Requirement already satisfied: setproctitle in d:\conda\envs\torch_1_9\lib\site-packages (from wandb) (1.3.2)
# Requirement already satisfied: requests<3,>=2.0.0 in d:\conda\envs\torch_1_9\lib\site-packages (from wandb) (2.27.1)
# Requirement already satisfied: GitPython>=1.0.0 in d:\conda\envs\torch_1_9\lib\site-packages (from wandb) (3.1.29)
# Requirement already satisfied: docker-pycreds>=0.4.0 in d:\conda\envs\torch_1_9\lib\site-packages (from wandb) (0.4.0)
# Requirement already satisfied: Click!=8.0.0,>=7.0 in d:\conda\envs\torch_1_9\lib\site-packages (from wandb) (8.0.4)
# Requirement already satisfied: colorama in d:\conda\envs\torch_1_9\lib\site-packages (from Click!=8.0.0,>=7.0->wandb) (0.4.4)
# Requirement already satisfied: gitdb<5,>=4.0.1 in d:\conda\envs\torch_1_9\lib\site-packages (from GitPython>=1.0.0->wandb) (4.0.9)
# Requirement already satisfied: smmap<6,>=3.0.1 in d:\conda\envs\torch_1_9\lib\site-packages (from gitdb<5,>=4.0.1->GitPython>=1.0.0->wandb) (5.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\conda\envs\torch_1_9\lib\site-packages (from requests<3,>=2.0.0->wandb) (2022.6.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in d:\conda\envs\torch_1_9\lib\site-packages (from requests<3,>=2.0.0->wandb) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\conda\envs\torch_1_9\lib\site-packages (from requests<3,>=2.0.0->wandb) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\conda\envs\torch_1_9\lib\site-packages (from requests<3,>=2.0.0->wandb) (1.26.12)

# %%
# !wandb login cd60939d994ad74190b61e223efd4acaca58bc11
# Out:
# wandb: Appending key for api.wandb.ai to your netrc file: C:\Users\user/.netrc

# %%
import wandb

wandb.login()
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: andrew_tep. Use `wandb login --relogin` to force relogin
# True

# %%
wandb.init(project="face_or_profile")
# Out:
# Finishing last run (ID:2qwrsh51) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# Synced <strong style="color:#cdcd00">logical-disco-11</strong>: <a href="https://wandb.ai/andrew_tep/face_or_profile/runs/2qwrsh51" target="_blank">https://wandb.ai/andrew_tep/face_or_profile/runs/2qwrsh51</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20221012_175103-2qwrsh51\logs</code>
# Successfully finished last run (ID:2qwrsh51). Initializing new run:<br/>
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016933333330477276, max=1.0…
# Tracking run with wandb version 0.13.4
# Run data is saved locally in <code>C:\Users\user\Downloads\public_attach\wandb\run-20221012_175113-38u0njn3</code>
# Syncing run <strong><a href="https://wandb.ai/andrew_tep/face_or_profile/runs/38u0njn3" target="_blank">fragrant-wind-12</a></strong> to <a href="https://wandb.ai/andrew_tep/face_or_profile" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src="https://wandb.ai/andrew_tep/face_or_profile/runs/38u0njn3?jupyter=true" style="border:none;width:100%;height:420px;display:none;"></iframe>

# %%
wandb.init(config = {
  "learning_rate": 1e-4,
  "epochs": 5,
  "batch_size": 128
})
# Out:
# Finishing last run (ID:38u0njn3) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# Synced <strong style="color:#cdcd00">fragrant-wind-12</strong>: <a href="https://wandb.ai/andrew_tep/face_or_profile/runs/38u0njn3" target="_blank">https://wandb.ai/andrew_tep/face_or_profile/runs/38u0njn3</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20221012_175113-38u0njn3\logs</code>
# Successfully finished last run (ID:38u0njn3). Initializing new run:<br/>
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016666666666666666, max=1.0…
# Tracking run with wandb version 0.13.4
# Run data is saved locally in <code>C:\Users\user\Downloads\public_attach\wandb\run-20221012_175130-1k7eeyuh</code>
# Syncing run <strong><a href="https://wandb.ai/andrew_tep/uncategorized/runs/1k7eeyuh" target="_blank">lyric-planet-7</a></strong> to <a href="https://wandb.ai/andrew_tep/uncategorized" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src="https://wandb.ai/andrew_tep/uncategorized/runs/1k7eeyuh?jupyter=true" style="border:none;width:100%;height:420px;display:none;"></iframe>

# %%
import random 
SEED = 2345345

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)
torch.backends.cudnn.deterministic = True

# %%
TRAIN_DIR = Path('train')
TEST_DIR = Path('test')
DATA_MODES = ['train', 'val', 'test']
RESCALE_SIZE = 224
DEVICE = 'cuda:0' if torch.cuda.is_available() else 'cpu'
CUDA_LAUNCH_BLOCKING=1
BATCH_SIZE=128

print(DEVICE)
# Out:
# cuda:0

# %%
TEST_DIR
# Out:
# WindowsPath('test')

# %%
class FaceDataset(Dataset):
    def __init__(self, files, mode):
        super().__init__()
        self.files = sorted(files)
        self.mode = mode
        
        if self.mode not in DATA_MODES:
            print("This mode is not corresct")
            
        self.len_ = len(self.files)
        
        self.label_encoder = LabelEncoder()
        
        if self.mode != "test":
            self.labels = [path.parent.name for path in self.files]
            self.label_encoder.fit(self.labels)
            
            with open('label_encoder.pkl', 'wb') as le_dump_file:
                  pickle.dump(self.label_encoder, le_dump_file)
                    
                    
    def __len__(self):
        return self.len_
    
    def load_sample(self, file):
        image = Image.open(file)
        image.load()
        return image
    
    def __getitem__(self, index):
        transform = transforms.Compose([
            transforms.ToTensor(),
            transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]) 
        ])
        
        data_transforms = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
        transforms.RandomVerticalFlip(p=0.5),
        transforms.RandomHorizontalFlip(p=0.5),])
        
        x = self.load_sample(self.files[index])
        x = self._prepare_sample(x)
        x = np.array(x/255, dtype = 'float32')
        if self.mode == 'train':
            x = data_transforms(x)
        else:
            x = transform(x)
            
        if self.mode == "test":
            return x
        else:
            label = self.labels[index]
            label_id = self.label_encoder.transform([label])
            y = label_id.item()
            return x, y
        
    def _prepare_sample(self, image):
        image = image.resize((RESCALE_SIZE, RESCALE_SIZE))
        return np.array(image)

# %%
train_val_files = sorted(list(TRAIN_DIR.rglob('*.png')))
test_files = (list(TEST_DIR.glob('*.png')))

from sklearn.model_selection import train_test_split

train_val_labels = [path.parent.name for path in train_val_files]
train_files, val_files = train_test_split(train_val_files, test_size=0.25, \
                                          stratify=train_val_labels)

# %%
test_files
# Out:
# [WindowsPath('test/ 1.png'),
#  WindowsPath('test/ 10.png'),
#  WindowsPath('test/ 100.png'),
#  WindowsPath('test/ 1000.png'),
#  WindowsPath('test/ 10000.png'),
#  WindowsPath('test/ 10001.png'),
#  WindowsPath('test/ 10002.png'),
#  WindowsPath('test/ 10003.png'),
#  WindowsPath('test/ 10004.png'),
#  WindowsPath('test/ 10005.png'),
#  WindowsPath('test/ 10006.png'),
#  WindowsPath('test/ 10007.png'),
#  WindowsPath('test/ 10008.png'),
#  WindowsPath('test/ 10009.png'),
#  WindowsPath('test/ 1001.png'),
#  WindowsPath('test/ 10010.png'),
#  WindowsPath('test/ 10011.png'),
#  WindowsPath('test/ 10012.png'),
#  WindowsPath('test/ 10013.png'),
#  WindowsPath('test/ 10014.png'),
#  WindowsPath('test/ 10015.png'),
#  WindowsPath('test/ 10016.png'),
#  WindowsPath('test/ 10017.png'),
#  WindowsPath('test/ 10018.png'),
#  WindowsPath('test/ 10019.png'),
#  WindowsPath('test/ 1002.png'),
#  WindowsPath('test/ 10020.png'),
#  WindowsPath('test/ 10021.png'),
#  WindowsPath('test/ 10022.png'),
#  WindowsPath('test/ 10023.png'),
#  WindowsPath('test/ 10024.png'),
#  WindowsPath('test/ 10025.png'),
#  WindowsPath('test/ 10026.png'),
#  WindowsPath('test/ 10027.png'),
#  WindowsPath('test/ 10028.png'),
#  WindowsPath('test/ 10029.png'),
#  WindowsPath('test/ 1003.png'),
#  WindowsPath('test/ 10030.png'),
#  WindowsPath('test/ 10031.png'),
#  WindowsPath('test/ 10032.png'),
#  WindowsPath('test/ 10033.png'),
#  WindowsPath('test/ 10034.png'),
#  WindowsPath('test/ 10035.png'),
#  WindowsPath('test/ 10036.png'),
#  WindowsPath('test/ 10037.png'),
#  WindowsPath('test/ 10038.png'),
#  WindowsPath('test/ 10039.png'),
#  WindowsPath('test/ 1004.png'),
#  WindowsPath('test/ 10040.png'),
#  WindowsPath('test/ 10041.png'),
#  WindowsPath('test/ 10042.png'),
#  WindowsPath('test/ 10043.png'),
#  WindowsPath('test/ 10044.png'),
#  WindowsPath('test/ 10045.png'),
#  WindowsPath('test/ 10046.png'),
#  WindowsPath('test/ 10047.png'),
#  WindowsPath('test/ 10048.png'),
#  WindowsPath('test/ 10049.png'),
#  WindowsPath('test/ 1005.png'),
#  WindowsPath('test/ 10050.png'),
#  WindowsPath('test/ 10051.png'),
#  WindowsPath('test/ 10052.png'),
#  WindowsPath('test/ 10053.png'),
#  WindowsPath('test/ 10054.png'),
#  WindowsPath('test/ 10055.png'),
#  WindowsPath('test/ 10056.png'),
#  WindowsPath('test/ 10057.png'),
#  WindowsPath('test/ 10058.png'),
#  WindowsPath('test/ 10059.png'),
#  WindowsPath('test/ 1006.png'),
#  WindowsPath('test/ 10060.png'),
#  WindowsPath('test/ 10061.png'),
#  WindowsPath('test/ 10062.png'),
#  WindowsPath('test/ 10063.png'),
#  WindowsPath('test/ 10064.png'),
#  WindowsPath('test/ 10065.png'),
#  WindowsPath('test/ 10066.png'),
#  WindowsPath('test/ 10067.png'),
#  WindowsPath('test/ 10068.png'),
#  WindowsPath('test/ 10069.png'),
#  WindowsPath('test/ 1007.png'),
#  WindowsPath('test/ 10070.png'),
#  WindowsPath('test/ 10071.png'),
#  WindowsPath('test/ 10072.png'),
#  WindowsPath('test/ 10073.png'),
#  WindowsPath('test/ 10074.png'),
#  WindowsPath('test/ 10075.png'),
#  WindowsPath('test/ 10076.png'),
#  WindowsPath('test/ 10077.png'),
#  WindowsPath('test/ 10078.png'),
#  WindowsPath('test/ 10079.png'),
#  WindowsPath('test/ 1008.png'),
#  WindowsPath('test/ 10080.png'),
#  WindowsPath('test/ 10081.png'),
#  WindowsPath('test/ 10082.png'),
#  WindowsPath('test/ 10083.png'),
#  WindowsPath('test/ 10084.png'),
#  WindowsPath('test/ 10085.png'),
#  WindowsPath('test/ 10086.png'),
#  WindowsPath('test/ 10087.png'),
#  WindowsPath('test/ 10088.png'),
#  WindowsPath('test/ 10089.png'),
#  WindowsPath('test/ 1009.png'),
#  WindowsPath('test/ 10090.png'),
#  WindowsPath('test/ 10091.png'),
#  WindowsPath('test/ 10092.png'),
#  WindowsPath('test/ 10093.png'),
#  WindowsPath('test/ 10094.png'),
#  WindowsPath('test/ 10095.png'),
#  WindowsPath('test/ 10096.png'),
#  WindowsPath('test/ 10097.png'),
#  WindowsPath('test/ 10098.png'),
#  WindowsPath('test/ 10099.png'),
#  WindowsPath('test/ 101.png'),
#  WindowsPath('test/ 1010.png'),
#  WindowsPath('test/ 10100.png'),
#  WindowsPath('test/ 10101.png'),
#  WindowsPath('test/ 10102.png'),
#  WindowsPath('test/ 10103.png'),
#  WindowsPath('test/ 10104.png'),
#  WindowsPath('test/ 10105.png'),
#  WindowsPath('test/ 10106.png'),
#  WindowsPath('test/ 10107.png'),
#  WindowsPath('test/ 10108.png'),
#  WindowsPath('test/ 10109.png'),
#  WindowsPath('test/ 1011.png'),
#  WindowsPath('test/ 10110.png'),
#  WindowsPath('test/ 10111.png'),
#  WindowsPath('test/ 10112.png'),
#  WindowsPath('test/ 10113.png'),
#  WindowsPath('test/ 10114.png'),
#  WindowsPath('test/ 10115.png'),
#  WindowsPath('test/ 10116.png'),
#  WindowsPath('test/ 10117.png'),
#  WindowsPath('test/ 10118.png'),
#  WindowsPath('test/ 10119.png'),
#  WindowsPath('test/ 1012.png'),
#  WindowsPath('test/ 10120.png'),
#  WindowsPath('test/ 10121.png'),
#  WindowsPath('test/ 10122.png'),
#  WindowsPath('test/ 10123.png'),
#  WindowsPath('test/ 10124.png'),
#  WindowsPath('test/ 10125.png'),
#  WindowsPath('test/ 10126.png'),
#  WindowsPath('test/ 10127.png'),
#  WindowsPath('test/ 10128.png'),
#  WindowsPath('test/ 10129.png'),
#  WindowsPath('test/ 1013.png'),
#  WindowsPath('test/ 10130.png'),
#  WindowsPath('test/ 10131.png'),
#  WindowsPath('test/ 10132.png'),
#  WindowsPath('test/ 10133.png'),
#  WindowsPath('test/ 10134.png'),
#  WindowsPath('test/ 10135.png'),
#  WindowsPath('test/ 10136.png'),
#  WindowsPath('test/ 10137.png'),
#  WindowsPath('test/ 10138.png'),
#  WindowsPath('test/ 10139.png'),
#  WindowsPath('test/ 1014.png'),
#  WindowsPath('test/ 10140.png'),
#  WindowsPath('test/ 10141.png'),
#  WindowsPath('test/ 10142.png'),
#  WindowsPath('test/ 10143.png'),
#  WindowsPath('test/ 10144.png'),
#  WindowsPath('test/ 10145.png'),
#  WindowsPath('test/ 10146.png'),
#  WindowsPath('test/ 10147.png'),
#  WindowsPath('test/ 10148.png'),
#  WindowsPath('test/ 10149.png'),
#  WindowsPath('test/ 1015.png'),
#  WindowsPath('test/ 10150.png'),
#  WindowsPath('test/ 10151.png'),
#  WindowsPath('test/ 10152.png'),
#  WindowsPath('test/ 10153.png'),
#  WindowsPath('test/ 10154.png'),
#  WindowsPath('test/ 10155.png'),
#  WindowsPath('test/ 10156.png'),
#  WindowsPath('test/ 10157.png'),
#  WindowsPath('test/ 10158.png'),
#  WindowsPath('test/ 10159.png'),
#  WindowsPath('test/ 1016.png'),
#  WindowsPath('test/ 10160.png'),
#  WindowsPath('test/ 10161.png'),
#  WindowsPath('test/ 10162.png'),
#  WindowsPath('test/ 10163.png'),
#  WindowsPath('test/ 10164.png'),
#  WindowsPath('test/ 10165.png'),
#  WindowsPath('test/ 10166.png'),
#  WindowsPath('test/ 10167.png'),
#  WindowsPath('test/ 10168.png'),
#  WindowsPath('test/ 10169.png'),
#  WindowsPath('test/ 1017.png'),
#  WindowsPath('test/ 10170.png'),
#  WindowsPath('test/ 10171.png'),
#  WindowsPath('test/ 10172.png'),
#  WindowsPath('test/ 10173.png'),
#  WindowsPath('test/ 10174.png'),
#  WindowsPath('test/ 10175.png'),
#  WindowsPath('test/ 10176.png'),
#  WindowsPath('test/ 10177.png'),
#  WindowsPath('test/ 10178.png'),
#  WindowsPath('test/ 10179.png'),
#  WindowsPath('test/ 1018.png'),
#  WindowsPath('test/ 10180.png'),
#  WindowsPath('test/ 10181.png'),
#  WindowsPath('test/ 10182.png'),
#  WindowsPath('test/ 10183.png'),
#  WindowsPath('test/ 10184.png'),
#  WindowsPath('test/ 10185.png'),
#  WindowsPath('test/ 10186.png'),
#  WindowsPath('test/ 10187.png'),
#  WindowsPath('test/ 10188.png'),
#  WindowsPath('test/ 10189.png'),
#  WindowsPath('test/ 1019.png'),
#  WindowsPath('test/ 10190.png'),
#  WindowsPath('test/ 10191.png'),
#  WindowsPath('test/ 10192.png'),
#  WindowsPath('test/ 10193.png'),
#  WindowsPath('test/ 10194.png'),
#  WindowsPath('test/ 10195.png'),
#  WindowsPath('test/ 10196.png'),
#  WindowsPath('test/ 10197.png'),
#  WindowsPath('test/ 10198.png'),
#  WindowsPath('test/ 10199.png'),
#  WindowsPath('test/ 102.png'),
#  WindowsPath('test/ 1020.png'),
#  WindowsPath('test/ 10200.png'),
#  WindowsPath('test/ 10201.png'),
#  WindowsPath('test/ 10202.png'),
#  WindowsPath('test/ 10203.png'),
#  WindowsPath('test/ 10204.png'),
#  WindowsPath('test/ 10205.png'),
#  WindowsPath('test/ 10206.png'),
#  WindowsPath('test/ 10207.png'),
#  WindowsPath('test/ 10208.png'),
#  WindowsPath('test/ 10209.png'),
#  WindowsPath('test/ 1021.png'),
#  WindowsPath('test/ 10210.png'),
#  WindowsPath('test/ 10211.png'),
#  WindowsPath('test/ 10212.png'),
#  WindowsPath('test/ 10213.png'),
#  WindowsPath('test/ 10214.png'),
#  WindowsPath('test/ 10215.png'),
#  WindowsPath('test/ 10216.png'),
#  WindowsPath('test/ 10217.png'),
#  WindowsPath('test/ 10218.png'),
#  WindowsPath('test/ 10219.png'),
#  WindowsPath('test/ 1022.png'),
#  WindowsPath('test/ 10220.png'),
#  WindowsPath('test/ 10221.png'),
#  WindowsPath('test/ 10222.png'),
#  WindowsPath('test/ 10223.png'),
#  WindowsPath('test/ 10225.png'),
#  WindowsPath('test/ 10226.png'),
#  WindowsPath('test/ 10227.png'),
#  WindowsPath('test/ 10228.png'),
#  WindowsPath('test/ 10229.png'),
#  WindowsPath('test/ 1023.png'),
#  WindowsPath('test/ 10230.png'),
#  WindowsPath('test/ 10231.png'),
#  WindowsPath('test/ 10232.png'),
#  WindowsPath('test/ 10233.png'),
#  WindowsPath('test/ 10234.png'),
#  WindowsPath('test/ 10235.png'),
#  WindowsPath('test/ 10236.png'),
#  WindowsPath('test/ 10237.png'),
#  WindowsPath('test/ 10238.png'),
#  WindowsPath('test/ 10239.png'),
#  WindowsPath('test/ 1024.png'),
#  WindowsPath('test/ 10240.png'),
#  WindowsPath('test/ 10241.png'),
#  WindowsPath('test/ 10242.png'),
#  WindowsPath('test/ 10244.png'),
#  WindowsPath('test/ 10245.png'),
#  WindowsPath('test/ 10246.png'),
#  WindowsPath('test/ 10247.png'),
#  WindowsPath('test/ 10248.png'),
#  WindowsPath('test/ 10249.png'),
#  WindowsPath('test/ 1025.png'),
#  WindowsPath('test/ 10250.png'),
#  WindowsPath('test/ 10251.png'),
#  WindowsPath('test/ 10252.png'),
#  WindowsPath('test/ 10253.png'),
#  WindowsPath('test/ 10254.png'),
#  WindowsPath('test/ 10255.png'),
#  WindowsPath('test/ 10256.png'),
#  WindowsPath('test/ 10257.png'),
#  WindowsPath('test/ 10258.png'),
#  WindowsPath('test/ 10259.png'),
#  WindowsPath('test/ 1026.png'),
#  WindowsPath('test/ 10260.png'),
#  WindowsPath('test/ 10261.png'),
#  WindowsPath('test/ 10262.png'),
#  WindowsPath('test/ 10263.png'),
#  WindowsPath('test/ 10264.png'),
#  WindowsPath('test/ 10265.png'),
#  WindowsPath('test/ 10266.png'),
#  WindowsPath('test/ 10267.png'),
#  WindowsPath('test/ 10268.png'),
#  WindowsPath('test/ 10269.png'),
#  WindowsPath('test/ 1027.png'),
#  WindowsPath('test/ 10270.png'),
#  WindowsPath('test/ 10271.png'),
#  WindowsPath('test/ 10272.png'),
#  WindowsPath('test/ 10273.png'),
#  WindowsPath('test/ 10274.png'),
#  WindowsPath('test/ 10275.png'),
#  WindowsPath('test/ 10276.png'),
#  WindowsPath('test/ 10277.png'),
#  WindowsPath('test/ 10278.png'),
#  WindowsPath('test/ 10279.png'),
#  WindowsPath('test/ 1028.png'),
#  WindowsPath('test/ 10280.png'),
#  WindowsPath('test/ 10281.png'),
#  WindowsPath('test/ 10282.png'),
#  WindowsPath('test/ 10283.png'),
#  WindowsPath('test/ 10284.png'),
#  WindowsPath('test/ 10285.png'),
#  WindowsPath('test/ 10286.png'),
#  WindowsPath('test/ 10287.png'),
#  WindowsPath('test/ 10288.png'),
#  WindowsPath('test/ 10289.png'),
#  WindowsPath('test/ 1029.png'),
#  WindowsPath('test/ 10290.png'),
#  WindowsPath('test/ 10291.png'),
#  WindowsPath('test/ 10292.png'),
#  WindowsPath('test/ 10293.png'),
#  WindowsPath('test/ 10294.png'),
#  WindowsPath('test/ 10295.png'),
#  WindowsPath('test/ 10296.png'),
#  WindowsPath('test/ 10297.png'),
#  WindowsPath('test/ 10298.png'),
#  WindowsPath('test/ 10299.png'),
#  WindowsPath('test/ 103.png'),
#  WindowsPath('test/ 1030.png'),
#  WindowsPath('test/ 10300.png'),
#  WindowsPath('test/ 10301.png'),
#  WindowsPath('test/ 10302.png'),
#  WindowsPath('test/ 10303.png'),
#  WindowsPath('test/ 10304.png'),
#  WindowsPath('test/ 10305.png'),
#  WindowsPath('test/ 10306.png'),
#  WindowsPath('test/ 10307.png'),
#  WindowsPath('test/ 10308.png'),
#  WindowsPath('test/ 10309.png'),
#  WindowsPath('test/ 1031.png'),
#  WindowsPath('test/ 10310.png'),
#  WindowsPath('test/ 10311.png'),
#  WindowsPath('test/ 10312.png'),
#  WindowsPath('test/ 10313.png'),
#  WindowsPath('test/ 10314.png'),
#  WindowsPath('test/ 10315.png'),
#  WindowsPath('test/ 10316.png'),
#  WindowsPath('test/ 10317.png'),
#  WindowsPath('test/ 10318.png'),
#  WindowsPath('test/ 10319.png'),
#  WindowsPath('test/ 1032.png'),
#  WindowsPath('test/ 10320.png'),
#  WindowsPath('test/ 10321.png'),
#  WindowsPath('test/ 10322.png'),
#  WindowsPath('test/ 10323.png'),
#  WindowsPath('test/ 10324.png'),
#  WindowsPath('test/ 10325.png'),
#  WindowsPath('test/ 10326.png'),
#  WindowsPath('test/ 10327.png'),
#  WindowsPath('test/ 10328.png'),
#  WindowsPath('test/ 10329.png'),
#  WindowsPath('test/ 1033.png'),
#  WindowsPath('test/ 10330.png'),
#  WindowsPath('test/ 10331.png'),
#  WindowsPath('test/ 10332.png'),
#  WindowsPath('test/ 10333.png'),
#  WindowsPath('test/ 10334.png'),
#  WindowsPath('test/ 10335.png'),
#  WindowsPath('test/ 10336.png'),
#  WindowsPath('test/ 10337.png'),
#  WindowsPath('test/ 10338.png'),
#  WindowsPath('test/ 10339.png'),
#  WindowsPath('test/ 1034.png'),
#  WindowsPath('test/ 10340.png'),
#  WindowsPath('test/ 10341.png'),
#  WindowsPath('test/ 10342.png'),
#  WindowsPath('test/ 10343.png'),
#  WindowsPath('test/ 10344.png'),
#  WindowsPath('test/ 10345.png'),
#  WindowsPath('test/ 10346.png'),
#  WindowsPath('test/ 10347.png'),
#  WindowsPath('test/ 10348.png'),
#  WindowsPath('test/ 10349.png'),
#  WindowsPath('test/ 1035.png'),
#  WindowsPath('test/ 10350.png'),
#  WindowsPath('test/ 10351.png'),
#  WindowsPath('test/ 10352.png'),
#  WindowsPath('test/ 10353.png'),
#  WindowsPath('test/ 10354.png'),
#  WindowsPath('test/ 10355.png'),
#  WindowsPath('test/ 10356.png'),
#  WindowsPath('test/ 10357.png'),
#  WindowsPath('test/ 10358.png'),
#  WindowsPath('test/ 10359.png'),
#  WindowsPath('test/ 1036.png'),
#  WindowsPath('test/ 10360.png'),
#  WindowsPath('test/ 10361.png'),
#  WindowsPath('test/ 10362.png'),
#  WindowsPath('test/ 10363.png'),
#  WindowsPath('test/ 10364.png'),
#  WindowsPath('test/ 10365.png'),
#  WindowsPath('test/ 10366.png'),
#  WindowsPath('test/ 10367.png'),
#  WindowsPath('test/ 10368.png'),
#  WindowsPath('test/ 10369.png'),
#  WindowsPath('test/ 1037.png'),
#  WindowsPath('test/ 10370.png'),
#  WindowsPath('test/ 10371.png'),
#  WindowsPath('test/ 10372.png'),
#  WindowsPath('test/ 10373.png'),
#  WindowsPath('test/ 10374.png'),
#  WindowsPath('test/ 10375.png'),
#  WindowsPath('test/ 10376.png'),
#  WindowsPath('test/ 10377.png'),
#  WindowsPath('test/ 10378.png'),
#  WindowsPath('test/ 10379.png'),
#  WindowsPath('test/ 1038.png'),
#  WindowsPath('test/ 10380.png'),
#  WindowsPath('test/ 10381.png'),
#  WindowsPath('test/ 10382.png'),
#  WindowsPath('test/ 10383.png'),
#  WindowsPath('test/ 10384.png'),
#  WindowsPath('test/ 10385.png'),
#  WindowsPath('test/ 10386.png'),
#  WindowsPath('test/ 10387.png'),
#  WindowsPath('test/ 10388.png'),
#  WindowsPath('test/ 10389.png'),
#  WindowsPath('test/ 1039.png'),
#  WindowsPath('test/ 10390.png'),
#  WindowsPath('test/ 10391.png'),
#  WindowsPath('test/ 10392.png'),
#  WindowsPath('test/ 10393.png'),
#  WindowsPath('test/ 10394.png'),
#  WindowsPath('test/ 10395.png'),
#  WindowsPath('test/ 10396.png'),
#  WindowsPath('test/ 10397.png'),
#  WindowsPath('test/ 10398.png'),
#  WindowsPath('test/ 10399.png'),
#  WindowsPath('test/ 104.png'),
#  WindowsPath('test/ 1040.png'),
#  WindowsPath('test/ 10400.png'),
#  WindowsPath('test/ 10401.png'),
#  WindowsPath('test/ 10402.png'),
#  WindowsPath('test/ 10403.png'),
#  WindowsPath('test/ 10404.png'),
#  WindowsPath('test/ 10405.png'),
#  WindowsPath('test/ 10406.png'),
#  WindowsPath('test/ 10407.png'),
#  WindowsPath('test/ 10408.png'),
#  WindowsPath('test/ 10409.png'),
#  WindowsPath('test/ 1041.png'),
#  WindowsPath('test/ 10410.png'),
#  WindowsPath('test/ 10411.png'),
#  WindowsPath('test/ 10412.png'),
#  WindowsPath('test/ 10413.png'),
#  WindowsPath('test/ 10414.png'),
#  WindowsPath('test/ 10415.png'),
#  WindowsPath('test/ 10416.png'),
#  WindowsPath('test/ 10417.png'),
#  WindowsPath('test/ 10418.png'),
#  WindowsPath('test/ 10419.png'),
#  WindowsPath('test/ 1042.png'),
#  WindowsPath('test/ 10420.png'),
#  WindowsPath('test/ 10421.png'),
#  WindowsPath('test/ 10422.png'),
#  WindowsPath('test/ 10423.png'),
#  WindowsPath('test/ 10425.png'),
#  WindowsPath('test/ 10426.png'),
#  WindowsPath('test/ 10427.png'),
#  WindowsPath('test/ 10428.png'),
#  WindowsPath('test/ 10429.png'),
#  WindowsPath('test/ 1043.png'),
#  WindowsPath('test/ 10430.png'),
#  WindowsPath('test/ 10431.png'),
#  WindowsPath('test/ 10432.png'),
#  WindowsPath('test/ 10433.png'),
#  WindowsPath('test/ 10434.png'),
#  WindowsPath('test/ 10435.png'),
#  WindowsPath('test/ 10436.png'),
#  WindowsPath('test/ 10437.png'),
#  WindowsPath('test/ 10438.png'),
#  WindowsPath('test/ 10439.png'),
#  WindowsPath('test/ 1044.png'),
#  WindowsPath('test/ 10440.png'),
#  WindowsPath('test/ 10441.png'),
#  WindowsPath('test/ 10442.png'),
#  WindowsPath('test/ 10443.png'),
#  WindowsPath('test/ 10444.png'),
#  WindowsPath('test/ 10445.png'),
#  WindowsPath('test/ 10446.png'),
#  WindowsPath('test/ 10447.png'),
#  WindowsPath('test/ 10448.png'),
#  WindowsPath('test/ 10449.png'),
#  WindowsPath('test/ 1045.png'),
#  WindowsPath('test/ 10450.png'),
#  WindowsPath('test/ 10451.png'),
#  WindowsPath('test/ 10452.png'),
#  WindowsPath('test/ 10453.png'),
#  WindowsPath('test/ 10454.png'),
#  WindowsPath('test/ 10455.png'),
#  WindowsPath('test/ 10456.png'),
#  WindowsPath('test/ 10457.png'),
#  WindowsPath('test/ 10458.png'),
#  WindowsPath('test/ 10459.png'),
#  WindowsPath('test/ 1046.png'),
#  WindowsPath('test/ 10460.png'),
#  WindowsPath('test/ 10461.png'),
#  WindowsPath('test/ 10462.png'),
#  WindowsPath('test/ 10463.png'),
#  WindowsPath('test/ 10464.png'),
#  WindowsPath('test/ 10465.png'),
#  WindowsPath('test/ 10466.png'),
#  WindowsPath('test/ 10467.png'),
#  WindowsPath('test/ 10468.png'),
#  WindowsPath('test/ 10469.png'),
#  WindowsPath('test/ 1047.png'),
#  WindowsPath('test/ 10470.png'),
#  WindowsPath('test/ 10471.png'),
#  WindowsPath('test/ 10472.png'),
#  WindowsPath('test/ 10473.png'),
#  WindowsPath('test/ 10474.png'),
#  WindowsPath('test/ 10475.png'),
#  WindowsPath('test/ 10476.png'),
#  WindowsPath('test/ 10477.png'),
#  WindowsPath('test/ 10478.png'),
#  WindowsPath('test/ 10479.png'),
#  WindowsPath('test/ 1048.png'),
#  WindowsPath('test/ 10480.png'),
#  WindowsPath('test/ 10481.png'),
#  WindowsPath('test/ 10482.png'),
#  WindowsPath('test/ 10483.png'),
#  WindowsPath('test/ 10484.png'),
#  WindowsPath('test/ 10485.png'),
#  WindowsPath('test/ 10486.png'),
#  WindowsPath('test/ 10487.png'),
#  WindowsPath('test/ 10488.png'),
#  WindowsPath('test/ 10489.png'),
#  WindowsPath('test/ 1049.png'),
#  WindowsPath('test/ 10490.png'),
#  WindowsPath('test/ 10491.png'),
#  WindowsPath('test/ 10492.png'),
#  WindowsPath('test/ 10493.png'),
#  WindowsPath('test/ 10494.png'),
#  WindowsPath('test/ 10495.png'),
#  WindowsPath('test/ 10496.png'),
#  WindowsPath('test/ 10497.png'),
#  WindowsPath('test/ 10498.png'),
#  WindowsPath('test/ 10499.png'),
#  WindowsPath('test/ 105.png'),
#  WindowsPath('test/ 1050.png'),
#  WindowsPath('test/ 10500.png'),
#  WindowsPath('test/ 10501.png'),
#  WindowsPath('test/ 10502.png'),
#  WindowsPath('test/ 10503.png'),
#  WindowsPath('test/ 10504.png'),
#  WindowsPath('test/ 10505.png'),
#  WindowsPath('test/ 10506.png'),
#  WindowsPath('test/ 10507.png'),
#  WindowsPath('test/ 10508.png'),
#  WindowsPath('test/ 10509.png'),
#  WindowsPath('test/ 1051.png'),
#  WindowsPath('test/ 10510.png'),
#  WindowsPath('test/ 10511.png'),
#  WindowsPath('test/ 10512.png'),
#  WindowsPath('test/ 10513.png'),
#  WindowsPath('test/ 10514.png'),
#  WindowsPath('test/ 10515.png'),
#  WindowsPath('test/ 10516.png'),
#  WindowsPath('test/ 10517.png'),
#  WindowsPath('test/ 10518.png'),
#  WindowsPath('test/ 10519.png'),
#  WindowsPath('test/ 1052.png'),
#  WindowsPath('test/ 10520.png'),
#  WindowsPath('test/ 10521.png'),
#  WindowsPath('test/ 10522.png'),
#  WindowsPath('test/ 10523.png'),
#  WindowsPath('test/ 10524.png'),
#  WindowsPath('test/ 10525.png'),
#  WindowsPath('test/ 10526.png'),
#  WindowsPath('test/ 10527.png'),
#  WindowsPath('test/ 10528.png'),
#  WindowsPath('test/ 10529.png'),
#  WindowsPath('test/ 1053.png'),
#  WindowsPath('test/ 10530.png'),
#  WindowsPath('test/ 10531.png'),
#  WindowsPath('test/ 10532.png'),
#  WindowsPath('test/ 10533.png'),
#  WindowsPath('test/ 10534.png'),
#  WindowsPath('test/ 10535.png'),
#  WindowsPath('test/ 10536.png'),
#  WindowsPath('test/ 10537.png'),
#  WindowsPath('test/ 10538.png'),
#  WindowsPath('test/ 10539.png'),
#  WindowsPath('test/ 1054.png'),
#  WindowsPath('test/ 10540.png'),
#  WindowsPath('test/ 10541.png'),
#  WindowsPath('test/ 10542.png'),
#  WindowsPath('test/ 10543.png'),
#  WindowsPath('test/ 10544.png'),
#  WindowsPath('test/ 10545.png'),
#  WindowsPath('test/ 10546.png'),
#  WindowsPath('test/ 10547.png'),
#  WindowsPath('test/ 10548.png'),
#  WindowsPath('test/ 10549.png'),
#  WindowsPath('test/ 1055.png'),
#  WindowsPath('test/ 10550.png'),
#  WindowsPath('test/ 10551.png'),
#  WindowsPath('test/ 10552.png'),
#  WindowsPath('test/ 10553.png'),
#  WindowsPath('test/ 10554.png'),
#  WindowsPath('test/ 10555.png'),
#  WindowsPath('test/ 10556.png'),
#  WindowsPath('test/ 10557.png'),
#  WindowsPath('test/ 10558.png'),
#  WindowsPath('test/ 10559.png'),
#  WindowsPath('test/ 1056.png'),
#  WindowsPath('test/ 10560.png'),
#  WindowsPath('test/ 10561.png'),
#  WindowsPath('test/ 10563.png'),
#  WindowsPath('test/ 10564.png'),
#  WindowsPath('test/ 10565.png'),
#  WindowsPath('test/ 10566.png'),
#  WindowsPath('test/ 10567.png'),
#  WindowsPath('test/ 10568.png'),
#  WindowsPath('test/ 10569.png'),
#  WindowsPath('test/ 1057.png'),
#  WindowsPath('test/ 10570.png'),
#  WindowsPath('test/ 10571.png'),
#  WindowsPath('test/ 10572.png'),
#  WindowsPath('test/ 10573.png'),
#  WindowsPath('test/ 10574.png'),
#  WindowsPath('test/ 10575.png'),
#  WindowsPath('test/ 10576.png'),
#  WindowsPath('test/ 10577.png'),
#  WindowsPath('test/ 10578.png'),
#  WindowsPath('test/ 10579.png'),
#  WindowsPath('test/ 1058.png'),
#  WindowsPath('test/ 10580.png'),
#  WindowsPath('test/ 10581.png'),
#  WindowsPath('test/ 10582.png'),
#  WindowsPath('test/ 10583.png'),
#  WindowsPath('test/ 10584.png'),
#  WindowsPath('test/ 10585.png'),
#  WindowsPath('test/ 10586.png'),
#  WindowsPath('test/ 10587.png'),
#  WindowsPath('test/ 10588.png'),
#  WindowsPath('test/ 10589.png'),
#  WindowsPath('test/ 1059.png'),
#  WindowsPath('test/ 10590.png'),
#  WindowsPath('test/ 10591.png'),
#  WindowsPath('test/ 10592.png'),
#  WindowsPath('test/ 10593.png'),
#  WindowsPath('test/ 10594.png'),
#  WindowsPath('test/ 10596.png'),
#  WindowsPath('test/ 10597.png'),
#  WindowsPath('test/ 10598.png'),
#  WindowsPath('test/ 10599.png'),
#  WindowsPath('test/ 106.png'),
#  WindowsPath('test/ 1060.png'),
#  WindowsPath('test/ 10600.png'),
#  WindowsPath('test/ 10601.png'),
#  WindowsPath('test/ 10602.png'),
#  WindowsPath('test/ 10603.png'),
#  WindowsPath('test/ 10604.png'),
#  WindowsPath('test/ 10605.png'),
#  WindowsPath('test/ 10606.png'),
#  WindowsPath('test/ 10607.png'),
#  WindowsPath('test/ 10608.png'),
#  WindowsPath('test/ 10609.png'),
#  WindowsPath('test/ 1061.png'),
#  WindowsPath('test/ 10610.png'),
#  WindowsPath('test/ 10611.png'),
#  WindowsPath('test/ 10612.png'),
#  WindowsPath('test/ 10613.png'),
#  WindowsPath('test/ 10614.png'),
#  WindowsPath('test/ 10615.png'),
#  WindowsPath('test/ 10616.png'),
#  WindowsPath('test/ 10617.png'),
#  WindowsPath('test/ 10618.png'),
#  WindowsPath('test/ 10619.png'),
#  WindowsPath('test/ 1062.png'),
#  WindowsPath('test/ 10620.png'),
#  WindowsPath('test/ 10621.png'),
#  WindowsPath('test/ 10622.png'),
#  WindowsPath('test/ 10623.png'),
#  WindowsPath('test/ 10624.png'),
#  WindowsPath('test/ 10625.png'),
#  WindowsPath('test/ 10626.png'),
#  WindowsPath('test/ 10627.png'),
#  WindowsPath('test/ 10628.png'),
#  WindowsPath('test/ 10629.png'),
#  WindowsPath('test/ 1063.png'),
#  WindowsPath('test/ 10630.png'),
#  WindowsPath('test/ 10631.png'),
#  WindowsPath('test/ 10632.png'),
#  WindowsPath('test/ 10633.png'),
#  WindowsPath('test/ 10634.png'),
#  WindowsPath('test/ 10635.png'),
#  WindowsPath('test/ 10636.png'),
#  WindowsPath('test/ 10637.png'),
#  WindowsPath('test/ 10638.png'),
#  WindowsPath('test/ 10639.png'),
#  WindowsPath('test/ 1064.png'),
#  WindowsPath('test/ 10640.png'),
#  WindowsPath('test/ 10641.png'),
#  WindowsPath('test/ 10642.png'),
#  WindowsPath('test/ 10643.png'),
#  WindowsPath('test/ 10644.png'),
#  WindowsPath('test/ 10645.png'),
#  WindowsPath('test/ 10646.png'),
#  WindowsPath('test/ 10647.png'),
#  WindowsPath('test/ 10648.png'),
#  WindowsPath('test/ 10649.png'),
#  WindowsPath('test/ 1065.png'),
#  WindowsPath('test/ 10650.png'),
#  WindowsPath('test/ 10651.png'),
#  WindowsPath('test/ 10652.png'),
#  WindowsPath('test/ 10653.png'),
#  WindowsPath('test/ 10654.png'),
#  WindowsPath('test/ 10655.png'),
#  WindowsPath('test/ 10656.png'),
#  WindowsPath('test/ 10657.png'),
#  WindowsPath('test/ 10658.png'),
#  WindowsPath('test/ 10659.png'),
#  WindowsPath('test/ 1066.png'),
#  WindowsPath('test/ 10660.png'),
#  WindowsPath('test/ 10661.png'),
#  WindowsPath('test/ 10662.png'),
#  WindowsPath('test/ 10663.png'),
#  WindowsPath('test/ 10664.png'),
#  WindowsPath('test/ 10665.png'),
#  WindowsPath('test/ 10666.png'),
#  WindowsPath('test/ 10667.png'),
#  WindowsPath('test/ 10668.png'),
#  WindowsPath('test/ 1067.png'),
#  WindowsPath('test/ 10670.png'),
#  WindowsPath('test/ 10671.png'),
#  WindowsPath('test/ 10672.png'),
#  WindowsPath('test/ 10673.png'),
#  WindowsPath('test/ 10674.png'),
#  WindowsPath('test/ 10675.png'),
#  WindowsPath('test/ 10676.png'),
#  WindowsPath('test/ 10677.png'),
#  WindowsPath('test/ 10678.png'),
#  WindowsPath('test/ 10679.png'),
#  WindowsPath('test/ 1068.png'),
#  WindowsPath('test/ 10680.png'),
#  WindowsPath('test/ 10681.png'),
#  WindowsPath('test/ 10682.png'),
#  WindowsPath('test/ 10683.png'),
#  WindowsPath('test/ 10684.png'),
#  WindowsPath('test/ 10685.png'),
#  WindowsPath('test/ 10686.png'),
#  WindowsPath('test/ 10687.png'),
#  WindowsPath('test/ 10688.png'),
#  WindowsPath('test/ 10689.png'),
#  WindowsPath('test/ 1069.png'),
#  WindowsPath('test/ 10690.png'),
#  WindowsPath('test/ 10691.png'),
#  WindowsPath('test/ 10692.png'),
#  WindowsPath('test/ 10693.png'),
#  WindowsPath('test/ 10694.png'),
#  WindowsPath('test/ 10695.png'),
#  WindowsPath('test/ 10696.png'),
#  WindowsPath('test/ 10697.png'),
#  WindowsPath('test/ 10698.png'),
#  WindowsPath('test/ 10699.png'),
#  WindowsPath('test/ 107.png'),
#  WindowsPath('test/ 1070.png'),
#  WindowsPath('test/ 10700.png'),
#  WindowsPath('test/ 10701.png'),
#  WindowsPath('test/ 10702.png'),
#  WindowsPath('test/ 10703.png'),
#  WindowsPath('test/ 10704.png'),
#  WindowsPath('test/ 10705.png'),
#  WindowsPath('test/ 10706.png'),
#  WindowsPath('test/ 10707.png'),
#  WindowsPath('test/ 10708.png'),
#  WindowsPath('test/ 10709.png'),
#  WindowsPath('test/ 1071.png'),
#  WindowsPath('test/ 10710.png'),
#  WindowsPath('test/ 10711.png'),
#  WindowsPath('test/ 10712.png'),
#  WindowsPath('test/ 10713.png'),
#  WindowsPath('test/ 10714.png'),
#  WindowsPath('test/ 10715.png'),
#  WindowsPath('test/ 10716.png'),
#  WindowsPath('test/ 10717.png'),
#  WindowsPath('test/ 10718.png'),
#  WindowsPath('test/ 10719.png'),
#  WindowsPath('test/ 1072.png'),
#  WindowsPath('test/ 10720.png'),
#  WindowsPath('test/ 10721.png'),
#  WindowsPath('test/ 10722.png'),
#  WindowsPath('test/ 10723.png'),
#  WindowsPath('test/ 10725.png'),
#  WindowsPath('test/ 10726.png'),
#  WindowsPath('test/ 10727.png'),
#  WindowsPath('test/ 10728.png'),
#  WindowsPath('test/ 10729.png'),
#  WindowsPath('test/ 1073.png'),
#  WindowsPath('test/ 10730.png'),
#  WindowsPath('test/ 10731.png'),
#  WindowsPath('test/ 10732.png'),
#  WindowsPath('test/ 10733.png'),
#  WindowsPath('test/ 10734.png'),
#  WindowsPath('test/ 10735.png'),
#  WindowsPath('test/ 10736.png'),
#  WindowsPath('test/ 10737.png'),
#  WindowsPath('test/ 10738.png'),
#  WindowsPath('test/ 10739.png'),
#  WindowsPath('test/ 1074.png'),
#  WindowsPath('test/ 10740.png'),
#  WindowsPath('test/ 10741.png'),
#  WindowsPath('test/ 10742.png'),
#  WindowsPath('test/ 10743.png'),
#  WindowsPath('test/ 10744.png'),
#  WindowsPath('test/ 10745.png'),
#  WindowsPath('test/ 10746.png'),
#  WindowsPath('test/ 10747.png'),
#  WindowsPath('test/ 10748.png'),
#  WindowsPath('test/ 10749.png'),
#  WindowsPath('test/ 1075.png'),
#  WindowsPath('test/ 10750.png'),
#  WindowsPath('test/ 10751.png'),
#  WindowsPath('test/ 10752.png'),
#  WindowsPath('test/ 10753.png'),
#  WindowsPath('test/ 10754.png'),
#  WindowsPath('test/ 10755.png'),
#  WindowsPath('test/ 10756.png'),
#  WindowsPath('test/ 10757.png'),
#  WindowsPath('test/ 10758.png'),
#  WindowsPath('test/ 10759.png'),
#  WindowsPath('test/ 1076.png'),
#  WindowsPath('test/ 10760.png'),
#  WindowsPath('test/ 10761.png'),
#  WindowsPath('test/ 10762.png'),
#  WindowsPath('test/ 10763.png'),
#  WindowsPath('test/ 10764.png'),
#  WindowsPath('test/ 10765.png'),
#  WindowsPath('test/ 10766.png'),
#  WindowsPath('test/ 10767.png'),
#  WindowsPath('test/ 10768.png'),
#  WindowsPath('test/ 10769.png'),
#  WindowsPath('test/ 1077.png'),
#  WindowsPath('test/ 10770.png'),
#  WindowsPath('test/ 10771.png'),
#  WindowsPath('test/ 10772.png'),
#  WindowsPath('test/ 10773.png'),
#  WindowsPath('test/ 10774.png'),
#  WindowsPath('test/ 10775.png'),
#  WindowsPath('test/ 10776.png'),
#  WindowsPath('test/ 10777.png'),
#  WindowsPath('test/ 10778.png'),
#  WindowsPath('test/ 10779.png'),
#  WindowsPath('test/ 1078.png'),
#  WindowsPath('test/ 10780.png'),
#  WindowsPath('test/ 10781.png'),
#  WindowsPath('test/ 10782.png'),
#  WindowsPath('test/ 10783.png'),
#  WindowsPath('test/ 10784.png'),
#  WindowsPath('test/ 10785.png'),
#  WindowsPath('test/ 10786.png'),
#  WindowsPath('test/ 10787.png'),
#  WindowsPath('test/ 10788.png'),
#  WindowsPath('test/ 10789.png'),
#  WindowsPath('test/ 1079.png'),
#  WindowsPath('test/ 10790.png'),
#  WindowsPath('test/ 10791.png'),
#  WindowsPath('test/ 10792.png'),
#  WindowsPath('test/ 10793.png'),
#  WindowsPath('test/ 10794.png'),
#  WindowsPath('test/ 10795.png'),
#  WindowsPath('test/ 10796.png'),
#  WindowsPath('test/ 10797.png'),
#  WindowsPath('test/ 10798.png'),
#  WindowsPath('test/ 10799.png'),
#  WindowsPath('test/ 108.png'),
#  WindowsPath('test/ 1080.png'),
#  WindowsPath('test/ 10800.png'),
#  WindowsPath('test/ 10801.png'),
#  WindowsPath('test/ 10802.png'),
#  WindowsPath('test/ 10803.png'),
#  WindowsPath('test/ 10804.png'),
#  WindowsPath('test/ 10805.png'),
#  WindowsPath('test/ 10806.png'),
#  WindowsPath('test/ 10807.png'),
#  WindowsPath('test/ 10808.png'),
#  WindowsPath('test/ 10809.png'),
#  WindowsPath('test/ 1081.png'),
#  WindowsPath('test/ 10810.png'),
#  WindowsPath('test/ 10811.png'),
#  WindowsPath('test/ 10812.png'),
#  WindowsPath('test/ 10813.png'),
#  WindowsPath('test/ 10814.png'),
#  WindowsPath('test/ 10815.png'),
#  WindowsPath('test/ 10816.png'),
#  WindowsPath('test/ 10817.png'),
#  WindowsPath('test/ 10818.png'),
#  WindowsPath('test/ 10819.png'),
#  WindowsPath('test/ 1082.png'),
#  WindowsPath('test/ 10820.png'),
#  WindowsPath('test/ 10821.png'),
#  WindowsPath('test/ 10822.png'),
#  WindowsPath('test/ 10823.png'),
#  WindowsPath('test/ 10824.png'),
#  WindowsPath('test/ 10825.png'),
#  WindowsPath('test/ 10826.png'),
#  WindowsPath('test/ 10827.png'),
#  WindowsPath('test/ 10828.png'),
#  WindowsPath('test/ 10829.png'),
#  WindowsPath('test/ 1083.png'),
#  WindowsPath('test/ 10830.png'),
#  WindowsPath('test/ 10831.png'),
#  WindowsPath('test/ 10832.png'),
#  WindowsPath('test/ 10833.png'),
#  WindowsPath('test/ 10834.png'),
#  WindowsPath('test/ 10835.png'),
#  WindowsPath('test/ 10836.png'),
#  WindowsPath('test/ 10837.png'),
#  WindowsPath('test/ 10838.png'),
#  WindowsPath('test/ 10839.png'),
#  WindowsPath('test/ 1084.png'),
#  WindowsPath('test/ 10840.png'),
#  WindowsPath('test/ 10841.png'),
#  WindowsPath('test/ 10842.png'),
#  WindowsPath('test/ 10843.png'),
#  WindowsPath('test/ 10844.png'),
#  WindowsPath('test/ 10845.png'),
#  WindowsPath('test/ 10846.png'),
#  WindowsPath('test/ 10847.png'),
#  WindowsPath('test/ 10848.png'),
#  WindowsPath('test/ 10849.png'),
#  WindowsPath('test/ 1085.png'),
#  WindowsPath('test/ 10850.png'),
#  WindowsPath('test/ 10851.png'),
#  WindowsPath('test/ 10852.png'),
#  WindowsPath('test/ 10853.png'),
#  WindowsPath('test/ 10854.png'),
#  WindowsPath('test/ 10855.png'),
#  WindowsPath('test/ 10856.png'),
#  WindowsPath('test/ 10857.png'),
#  WindowsPath('test/ 10858.png'),
#  WindowsPath('test/ 10859.png'),
#  WindowsPath('test/ 1086.png'),
#  WindowsPath('test/ 10860.png'),
#  WindowsPath('test/ 10861.png'),
#  WindowsPath('test/ 10862.png'),
#  WindowsPath('test/ 10863.png'),
#  WindowsPath('test/ 10864.png'),
#  WindowsPath('test/ 10865.png'),
#  WindowsPath('test/ 10866.png'),
#  WindowsPath('test/ 10867.png'),
#  WindowsPath('test/ 10868.png'),
#  WindowsPath('test/ 10869.png'),
#  WindowsPath('test/ 1087.png'),
#  WindowsPath('test/ 10870.png'),
#  WindowsPath('test/ 10871.png'),
#  WindowsPath('test/ 10872.png'),
#  WindowsPath('test/ 10873.png'),
#  WindowsPath('test/ 10874.png'),
#  WindowsPath('test/ 10875.png'),
#  WindowsPath('test/ 10876.png'),
#  WindowsPath('test/ 10877.png'),
#  WindowsPath('test/ 10878.png'),
#  WindowsPath('test/ 10879.png'),
#  WindowsPath('test/ 1088.png'),
#  WindowsPath('test/ 10880.png'),
#  WindowsPath('test/ 10881.png'),
#  WindowsPath('test/ 10882.png'),
#  WindowsPath('test/ 10883.png'),
#  WindowsPath('test/ 10884.png'),
#  WindowsPath('test/ 10885.png'),
#  WindowsPath('test/ 10886.png'),
#  WindowsPath('test/ 10887.png'),
#  WindowsPath('test/ 10888.png'),
#  WindowsPath('test/ 10889.png'),
#  WindowsPath('test/ 1089.png'),
#  WindowsPath('test/ 10890.png'),
#  WindowsPath('test/ 10891.png'),
#  WindowsPath('test/ 10892.png'),
#  WindowsPath('test/ 10893.png'),
#  WindowsPath('test/ 10894.png'),
#  WindowsPath('test/ 10895.png'),
#  WindowsPath('test/ 10896.png'),
#  WindowsPath('test/ 10897.png'),
#  WindowsPath('test/ 10898.png'),
#  WindowsPath('test/ 10899.png'),
#  WindowsPath('test/ 1090.png'),
#  WindowsPath('test/ 10900.png'),
#  WindowsPath('test/ 10901.png'),
#  WindowsPath('test/ 10902.png'),
#  WindowsPath('test/ 10903.png'),
#  WindowsPath('test/ 10904.png'),
#  ...]

# %%
sorted(["10","1","2","6"])
# Out:
# ['1', '10', '2', '6']

# %%
n_classes = len(np.unique(train_val_labels))
n_classes
# Out:
# 2

# %%
train_labels = [path.parent.name for path in train_files] 
val_labels = [path.parent.name for path in val_files]

# %%
def create_dct_path_labels(train_files, train_labels):
    dct_simpsons = {}
    for label_i in np.unique(train_labels).tolist():
        dct_simpsons[label_i] = []

    for path_i, label_i in zip(train_files, train_labels):
        dct_simpsons[label_i].append(path_i)

    return dct_simpsons

def print_dct(dct_simpsons):
    for key in dct_simpsons:
        print(f"{key}\t{dct_simpsons[key]}")

# %%
dct_path_train = create_dct_path_labels(train_files, train_labels)

# %%
for person in dct_path_train:
    print(f"{person}\t{len(dct_path_train[person])}")
# Out:
# enface	9142
# profile	9029

# %%
def create_dct_from_labels(train_val_labels):
    dct_simpsons = {}
    for label_i in np.unique(train_val_labels).tolist():
        dct_simpsons.update({label_i:train_val_labels.count(label_i)})

    return dct_simpsons

new_train_files = []

for person in dct_path_train:
    new_train_files.extend(dct_path_train[person])

new_train_label = [path.parent.name for path in new_train_files]

# %%
val_dataset = FaceDataset(val_files, mode='val')
new_train_dataset = FaceDataset(new_train_files, mode='train')

# %%
def fit_epoch(model, train_dataloader, criterion, optimizer):
    running_loss = 0.0
    running_corrects = 0
    processed_data = 0
  
    for inputs, labels in train_dataloader:
        inputs = inputs.to(DEVICE) #перенос тензоров на видеокарту
        labels = labels.to(DEVICE)
        optimizer.zero_grad() #обнуляем градиенты, чтобы они не накапливались

        outputs = model(inputs) #прогоняем данные из трейнлоадера чеез нашу сеть (модель). интересно, почему не model.forward(inputs)?
        loss = criterion(outputs, labels) #считаем лосс
        loss.backward()
        optimizer.step()
        preds = torch.argmax(outputs, 1) #все, что больше 1, приводим к 1
        running_loss += loss.item() * inputs.size(0) #непонятно, как работает .size(0)
        running_corrects += torch.sum(preds == labels.data) #если предсказание совпадает с ответом, увеличиваем на 1 running_corrects
        processed_data += inputs.size(0) 
              
    train_loss = running_loss / processed_data #потери на трейне
    train_acc = running_corrects.cpu().numpy() / processed_data #точность на трейне
#     wandb.log({"loss": train_loss})
#     wandb.log({"train_acc": train_acc})
    return train_loss, train_acc

# %%
def eval_epoch(model, val_dataloader, criterion):
    model.eval()
    running_loss = 0.0
    running_corrects = 0
    processed_size = 0

    for inputs, labels in val_dataloader:
        inputs = inputs.to(DEVICE)
        labels = labels.to(DEVICE)

        with torch.set_grad_enabled(False):
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            preds = torch.argmax(outputs, 1)

        running_loss += loss.item() * inputs.size(0)
        running_corrects += torch.sum(preds == labels.data)
        processed_size += inputs.size(0)
    val_loss = running_loss / processed_size
    val_acc = running_corrects.double() / processed_size
    wandb.log({"loss_val": val_loss})
    wandb.log({"val_acc": val_acc})
    return val_loss, val_acc

# %%
def train(train_files, val_files, model, epochs, batch_size):
    train_dataloader = DataLoader(new_train_dataset, batch_size=BATCH_SIZE, shuffle=True)
    val_dataloader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False)

    history = []
    log_template = "\nEpoch {ep:03d} train_loss: {t_loss:0.4f} \
    val_loss {v_loss:0.4f} train_acc {t_acc:0.4f} val_acc {v_acc:0.4f}"

    with tqdm(desc="epoch", total=epochs) as pbar_outer:
        opt = torch.optim.Adam(model.parameters())
        criterion = nn.CrossEntropyLoss()

        for epoch in range(epochs):
            train_loss, train_acc = fit_epoch(model, train_dataloader, criterion, opt)
            wandb.log({"train_loss": train_loss})
            wandb.log({"train_acc": train_acc})
            print("loss", train_loss)
            
            val_loss, val_acc = eval_epoch(model, val_dataloader, criterion)
            history.append((train_loss, train_acc, val_loss, val_acc))
            
            pbar_outer.update(1)
            tqdm.write(log_template.format(ep=epoch+1, t_loss=train_loss,\
                                           v_loss=val_loss, t_acc=train_acc, v_acc=val_acc))
            
    return history

# %%
model = models.alexnet(pretrained=True)

# %%
for param in model.parameters():
    param.requires_grad = False

num_features = 9216
model.classifier = nn.Linear(num_features, n_classes)
model = model.to(DEVICE)

criterion = nn.BCELoss()
optimizer = optim.Adam(model.parameters(), lr=1e-4)

# %%
model_resnet = models.resnet34(pretrained=True)

for param in model_resnet.parameters():
    param.require_grad = False

num_features = model_resnet.fc.in_features
model_resnet.classifier = nn.Linear(num_features, n_classes)

if torch.cuda.is_available():
    model_resnet = model_resnet.cuda()
    print('Training with cuda')
    
model_resnet.classifier
# Out:
# Training with cuda
# Linear(in_features=512, out_features=2, bias=True)

# %%
# %%wandb
#
# history = train(new_train_dataset, val_dataset, model=model, epochs=25, batch_size=BATCH_SIZE)
# Out:
# <iframe src="https://wandb.ai/andrew_tep/uncategorized/runs/1k7eeyuh?jupyter=true" style="border:none;width:100%;height:420px;"></iframe>
# epoch:   0%|          | 0/25 [00:00<?, ?it/s]
# loss 0.022508517886814582
#
# Epoch 001 train_loss: 0.0225     val_loss 0.0521 train_acc 0.9954 val_acc 0.9903
# loss 0.01573429646794206
#
# Epoch 002 train_loss: 0.0157     val_loss 0.0479 train_acc 0.9961 val_acc 0.9926
# loss 0.01828465998065025
#
# Epoch 003 train_loss: 0.0183     val_loss 0.0565 train_acc 0.9959 val_acc 0.9911
# loss 0.018388053384578287
#
# Epoch 004 train_loss: 0.0184     val_loss 0.0659 train_acc 0.9961 val_acc 0.9894
# loss 0.02047137892855472
#
# Epoch 005 train_loss: 0.0205     val_loss 0.0457 train_acc 0.9960 val_acc 0.9934
# loss 0.029618750943535922
#
# Epoch 006 train_loss: 0.0296     val_loss 0.0488 train_acc 0.9949 val_acc 0.9929
# loss 0.017351706781718535
#
# Epoch 007 train_loss: 0.0174     val_loss 0.0665 train_acc 0.9960 val_acc 0.9901
# loss 0.014246633922634486
#
# Epoch 008 train_loss: 0.0142     val_loss 0.0617 train_acc 0.9970 val_acc 0.9908
# loss 0.017539239355534825
#
# Epoch 009 train_loss: 0.0175     val_loss 0.0939 train_acc 0.9968 val_acc 0.9851
# loss 0.01339232771324749
#
# Epoch 010 train_loss: 0.0134     val_loss 0.0644 train_acc 0.9973 val_acc 0.9903
# loss 0.011923040556868004
#
# Epoch 011 train_loss: 0.0119     val_loss 0.0633 train_acc 0.9970 val_acc 0.9917
# loss 0.01572595589128776
#
# Epoch 012 train_loss: 0.0157     val_loss 0.0505 train_acc 0.9970 val_acc 0.9934
# loss 0.014051791209432401
#
# Epoch 013 train_loss: 0.0141     val_loss 0.0539 train_acc 0.9972 val_acc 0.9936
# loss 0.02148839998579962
#
# Epoch 014 train_loss: 0.0215     val_loss 0.0683 train_acc 0.9964 val_acc 0.9927
# loss 0.010439913257136982
#
# Epoch 015 train_loss: 0.0104     val_loss 0.0684 train_acc 0.9981 val_acc 0.9921
# loss 0.009097805217183995
#
# Epoch 016 train_loss: 0.0091     val_loss 0.0621 train_acc 0.9988 val_acc 0.9926
# loss 0.016623010247855605
#
# Epoch 017 train_loss: 0.0166     val_loss 0.0682 train_acc 0.9960 val_acc 0.9906
# loss 0.009976726731802164
#
# Epoch 018 train_loss: 0.0100     val_loss 0.0909 train_acc 0.9973 val_acc 0.9904
# loss 0.013464696823988905
#
# Epoch 019 train_loss: 0.0135     val_loss 0.1202 train_acc 0.9971 val_acc 0.9863
# loss 0.008212751676267307
#
# Epoch 020 train_loss: 0.0082     val_loss 0.0760 train_acc 0.9980 val_acc 0.9916
# loss 0.009739912905389088
#
# Epoch 021 train_loss: 0.0097     val_loss 0.0881 train_acc 0.9979 val_acc 0.9903
# loss 0.008364578926885798
#
# Epoch 022 train_loss: 0.0084     val_loss 0.0756 train_acc 0.9977 val_acc 0.9911
# loss 0.010133770584816744
#
# Epoch 023 train_loss: 0.0101     val_loss 0.0931 train_acc 0.9977 val_acc 0.9917
# loss 0.012890171696162285
#
# Epoch 024 train_loss: 0.0129     val_loss 0.0725 train_acc 0.9978 val_acc 0.9919
# loss 0.006819860482998517
#
# Epoch 025 train_loss: 0.0068     val_loss 0.0637 train_acc 0.9985 val_acc 0.9931

# %%
def predict(model, test_loader):
    with torch.no_grad(): 
        logits = []
    
        for inputs in test_loader:
            inputs = inputs.to(DEVICE)
            model.eval()
            outputs = model(inputs).cpu()
            logits.append(outputs)
            
    probs = nn.functional.softmax(torch.cat(logits), dim=-1).numpy()
    return probs

# %%
def predict_one_sample(model, inputs, device=DEVICE):
    with torch.no_grad():
        inputs = inputs.to(device)
        model.eval()
        logit = model(inputs).cpu()
        probs = torch.nn.functional.softmax(logit, dim=-1).numpy()
    return probs

# %%
random_characters = int(np.random.uniform(0,1000))
ex_img, true_label = val_dataset[random_characters]
probs_im = predict_one_sample(model, ex_img.unsqueeze(0))

idxs = list(map(int, np.random.uniform(0,1000, 20)))
imgs = [val_dataset[id][0].unsqueeze(0) for id in idxs]

probs_ims = predict(model, imgs)

label_encoder = pickle.load(open("label_encoder.pkl", 'rb'))

y_pred = np.argmax(probs_ims,-1)

actual_labels = [val_dataset[id][1] for id in idxs]

preds_class = [label_encoder.classes_[i] for i in y_pred]

# %%
test_dataset = FaceDataset(test_files, mode="test")
test_loader = DataLoader(test_dataset, shuffle=False, batch_size=64)
probs = predict(model, test_loader) 

preds = label_encoder.inverse_transform(np.argmax(probs, axis=1)) 
test_filenames = [path.name for path in test_dataset.files]

# %%
test_filenames
# Out:
# [' 1.png',
#  ' 10.png',
#  ' 100.png',
#  ' 1000.png',
#  ' 10000.png',
#  ' 10001.png',
#  ' 10002.png',
#  ' 10003.png',
#  ' 10004.png',
#  ' 10005.png',
#  ' 10006.png',
#  ' 10007.png',
#  ' 10008.png',
#  ' 10009.png',
#  ' 1001.png',
#  ' 10010.png',
#  ' 10011.png',
#  ' 10012.png',
#  ' 10013.png',
#  ' 10014.png',
#  ' 10015.png',
#  ' 10016.png',
#  ' 10017.png',
#  ' 10018.png',
#  ' 10019.png',
#  ' 1002.png',
#  ' 10020.png',
#  ' 10021.png',
#  ' 10022.png',
#  ' 10023.png',
#  ' 10024.png',
#  ' 10025.png',
#  ' 10026.png',
#  ' 10027.png',
#  ' 10028.png',
#  ' 10029.png',
#  ' 1003.png',
#  ' 10030.png',
#  ' 10031.png',
#  ' 10032.png',
#  ' 10033.png',
#  ' 10034.png',
#  ' 10035.png',
#  ' 10036.png',
#  ' 10037.png',
#  ' 10038.png',
#  ' 10039.png',
#  ' 1004.png',
#  ' 10040.png',
#  ' 10041.png',
#  ' 10042.png',
#  ' 10043.png',
#  ' 10044.png',
#  ' 10045.png',
#  ' 10046.png',
#  ' 10047.png',
#  ' 10048.png',
#  ' 10049.png',
#  ' 1005.png',
#  ' 10050.png',
#  ' 10051.png',
#  ' 10052.png',
#  ' 10053.png',
#  ' 10054.png',
#  ' 10055.png',
#  ' 10056.png',
#  ' 10057.png',
#  ' 10058.png',
#  ' 10059.png',
#  ' 1006.png',
#  ' 10060.png',
#  ' 10061.png',
#  ' 10062.png',
#  ' 10063.png',
#  ' 10064.png',
#  ' 10065.png',
#  ' 10066.png',
#  ' 10067.png',
#  ' 10068.png',
#  ' 10069.png',
#  ' 1007.png',
#  ' 10070.png',
#  ' 10071.png',
#  ' 10072.png',
#  ' 10073.png',
#  ' 10074.png',
#  ' 10075.png',
#  ' 10076.png',
#  ' 10077.png',
#  ' 10078.png',
#  ' 10079.png',
#  ' 1008.png',
#  ' 10080.png',
#  ' 10081.png',
#  ' 10082.png',
#  ' 10083.png',
#  ' 10084.png',
#  ' 10085.png',
#  ' 10086.png',
#  ' 10087.png',
#  ' 10088.png',
#  ' 10089.png',
#  ' 1009.png',
#  ' 10090.png',
#  ' 10091.png',
#  ' 10092.png',
#  ' 10093.png',
#  ' 10094.png',
#  ' 10095.png',
#  ' 10096.png',
#  ' 10097.png',
#  ' 10098.png',
#  ' 10099.png',
#  ' 101.png',
#  ' 1010.png',
#  ' 10100.png',
#  ' 10101.png',
#  ' 10102.png',
#  ' 10103.png',
#  ' 10104.png',
#  ' 10105.png',
#  ' 10106.png',
#  ' 10107.png',
#  ' 10108.png',
#  ' 10109.png',
#  ' 1011.png',
#  ' 10110.png',
#  ' 10111.png',
#  ' 10112.png',
#  ' 10113.png',
#  ' 10114.png',
#  ' 10115.png',
#  ' 10116.png',
#  ' 10117.png',
#  ' 10118.png',
#  ' 10119.png',
#  ' 1012.png',
#  ' 10120.png',
#  ' 10121.png',
#  ' 10122.png',
#  ' 10123.png',
#  ' 10124.png',
#  ' 10125.png',
#  ' 10126.png',
#  ' 10127.png',
#  ' 10128.png',
#  ' 10129.png',
#  ' 1013.png',
#  ' 10130.png',
#  ' 10131.png',
#  ' 10132.png',
#  ' 10133.png',
#  ' 10134.png',
#  ' 10135.png',
#  ' 10136.png',
#  ' 10137.png',
#  ' 10138.png',
#  ' 10139.png',
#  ' 1014.png',
#  ' 10140.png',
#  ' 10141.png',
#  ' 10142.png',
#  ' 10143.png',
#  ' 10144.png',
#  ' 10145.png',
#  ' 10146.png',
#  ' 10147.png',
#  ' 10148.png',
#  ' 10149.png',
#  ' 1015.png',
#  ' 10150.png',
#  ' 10151.png',
#  ' 10152.png',
#  ' 10153.png',
#  ' 10154.png',
#  ' 10155.png',
#  ' 10156.png',
#  ' 10157.png',
#  ' 10158.png',
#  ' 10159.png',
#  ' 1016.png',
#  ' 10160.png',
#  ' 10161.png',
#  ' 10162.png',
#  ' 10163.png',
#  ' 10164.png',
#  ' 10165.png',
#  ' 10166.png',
#  ' 10167.png',
#  ' 10168.png',
#  ' 10169.png',
#  ' 1017.png',
#  ' 10170.png',
#  ' 10171.png',
#  ' 10172.png',
#  ' 10173.png',
#  ' 10174.png',
#  ' 10175.png',
#  ' 10176.png',
#  ' 10177.png',
#  ' 10178.png',
#  ' 10179.png',
#  ' 1018.png',
#  ' 10180.png',
#  ' 10181.png',
#  ' 10182.png',
#  ' 10183.png',
#  ' 10184.png',
#  ' 10185.png',
#  ' 10186.png',
#  ' 10187.png',
#  ' 10188.png',
#  ' 10189.png',
#  ' 1019.png',
#  ' 10190.png',
#  ' 10191.png',
#  ' 10192.png',
#  ' 10193.png',
#  ' 10194.png',
#  ' 10195.png',
#  ' 10196.png',
#  ' 10197.png',
#  ' 10198.png',
#  ' 10199.png',
#  ' 102.png',
#  ' 1020.png',
#  ' 10200.png',
#  ' 10201.png',
#  ' 10202.png',
#  ' 10203.png',
#  ' 10204.png',
#  ' 10205.png',
#  ' 10206.png',
#  ' 10207.png',
#  ' 10208.png',
#  ' 10209.png',
#  ' 1021.png',
#  ' 10210.png',
#  ' 10211.png',
#  ' 10212.png',
#  ' 10213.png',
#  ' 10214.png',
#  ' 10215.png',
#  ' 10216.png',
#  ' 10217.png',
#  ' 10218.png',
#  ' 10219.png',
#  ' 1022.png',
#  ' 10220.png',
#  ' 10221.png',
#  ' 10222.png',
#  ' 10223.png',
#  ' 10225.png',
#  ' 10226.png',
#  ' 10227.png',
#  ' 10228.png',
#  ' 10229.png',
#  ' 1023.png',
#  ' 10230.png',
#  ' 10231.png',
#  ' 10232.png',
#  ' 10233.png',
#  ' 10234.png',
#  ' 10235.png',
#  ' 10236.png',
#  ' 10237.png',
#  ' 10238.png',
#  ' 10239.png',
#  ' 1024.png',
#  ' 10240.png',
#  ' 10241.png',
#  ' 10242.png',
#  ' 10244.png',
#  ' 10245.png',
#  ' 10246.png',
#  ' 10247.png',
#  ' 10248.png',
#  ' 10249.png',
#  ' 1025.png',
#  ' 10250.png',
#  ' 10251.png',
#  ' 10252.png',
#  ' 10253.png',
#  ' 10254.png',
#  ' 10255.png',
#  ' 10256.png',
#  ' 10257.png',
#  ' 10258.png',
#  ' 10259.png',
#  ' 1026.png',
#  ' 10260.png',
#  ' 10261.png',
#  ' 10262.png',
#  ' 10263.png',
#  ' 10264.png',
#  ' 10265.png',
#  ' 10266.png',
#  ' 10267.png',
#  ' 10268.png',
#  ' 10269.png',
#  ' 1027.png',
#  ' 10270.png',
#  ' 10271.png',
#  ' 10272.png',
#  ' 10273.png',
#  ' 10274.png',
#  ' 10275.png',
#  ' 10276.png',
#  ' 10277.png',
#  ' 10278.png',
#  ' 10279.png',
#  ' 1028.png',
#  ' 10280.png',
#  ' 10281.png',
#  ' 10282.png',
#  ' 10283.png',
#  ' 10284.png',
#  ' 10285.png',
#  ' 10286.png',
#  ' 10287.png',
#  ' 10288.png',
#  ' 10289.png',
#  ' 1029.png',
#  ' 10290.png',
#  ' 10291.png',
#  ' 10292.png',
#  ' 10293.png',
#  ' 10294.png',
#  ' 10295.png',
#  ' 10296.png',
#  ' 10297.png',
#  ' 10298.png',
#  ' 10299.png',
#  ' 103.png',
#  ' 1030.png',
#  ' 10300.png',
#  ' 10301.png',
#  ' 10302.png',
#  ' 10303.png',
#  ' 10304.png',
#  ' 10305.png',
#  ' 10306.png',
#  ' 10307.png',
#  ' 10308.png',
#  ' 10309.png',
#  ' 1031.png',
#  ' 10310.png',
#  ' 10311.png',
#  ' 10312.png',
#  ' 10313.png',
#  ' 10314.png',
#  ' 10315.png',
#  ' 10316.png',
#  ' 10317.png',
#  ' 10318.png',
#  ' 10319.png',
#  ' 1032.png',
#  ' 10320.png',
#  ' 10321.png',
#  ' 10322.png',
#  ' 10323.png',
#  ' 10324.png',
#  ' 10325.png',
#  ' 10326.png',
#  ' 10327.png',
#  ' 10328.png',
#  ' 10329.png',
#  ' 1033.png',
#  ' 10330.png',
#  ' 10331.png',
#  ' 10332.png',
#  ' 10333.png',
#  ' 10334.png',
#  ' 10335.png',
#  ' 10336.png',
#  ' 10337.png',
#  ' 10338.png',
#  ' 10339.png',
#  ' 1034.png',
#  ' 10340.png',
#  ' 10341.png',
#  ' 10342.png',
#  ' 10343.png',
#  ' 10344.png',
#  ' 10345.png',
#  ' 10346.png',
#  ' 10347.png',
#  ' 10348.png',
#  ' 10349.png',
#  ' 1035.png',
#  ' 10350.png',
#  ' 10351.png',
#  ' 10352.png',
#  ' 10353.png',
#  ' 10354.png',
#  ' 10355.png',
#  ' 10356.png',
#  ' 10357.png',
#  ' 10358.png',
#  ' 10359.png',
#  ' 1036.png',
#  ' 10360.png',
#  ' 10361.png',
#  ' 10362.png',
#  ' 10363.png',
#  ' 10364.png',
#  ' 10365.png',
#  ' 10366.png',
#  ' 10367.png',
#  ' 10368.png',
#  ' 10369.png',
#  ' 1037.png',
#  ' 10370.png',
#  ' 10371.png',
#  ' 10372.png',
#  ' 10373.png',
#  ' 10374.png',
#  ' 10375.png',
#  ' 10376.png',
#  ' 10377.png',
#  ' 10378.png',
#  ' 10379.png',
#  ' 1038.png',
#  ' 10380.png',
#  ' 10381.png',
#  ' 10382.png',
#  ' 10383.png',
#  ' 10384.png',
#  ' 10385.png',
#  ' 10386.png',
#  ' 10387.png',
#  ' 10388.png',
#  ' 10389.png',
#  ' 1039.png',
#  ' 10390.png',
#  ' 10391.png',
#  ' 10392.png',
#  ' 10393.png',
#  ' 10394.png',
#  ' 10395.png',
#  ' 10396.png',
#  ' 10397.png',
#  ' 10398.png',
#  ' 10399.png',
#  ' 104.png',
#  ' 1040.png',
#  ' 10400.png',
#  ' 10401.png',
#  ' 10402.png',
#  ' 10403.png',
#  ' 10404.png',
#  ' 10405.png',
#  ' 10406.png',
#  ' 10407.png',
#  ' 10408.png',
#  ' 10409.png',
#  ' 1041.png',
#  ' 10410.png',
#  ' 10411.png',
#  ' 10412.png',
#  ' 10413.png',
#  ' 10414.png',
#  ' 10415.png',
#  ' 10416.png',
#  ' 10417.png',
#  ' 10418.png',
#  ' 10419.png',
#  ' 1042.png',
#  ' 10420.png',
#  ' 10421.png',
#  ' 10422.png',
#  ' 10423.png',
#  ' 10425.png',
#  ' 10426.png',
#  ' 10427.png',
#  ' 10428.png',
#  ' 10429.png',
#  ' 1043.png',
#  ' 10430.png',
#  ' 10431.png',
#  ' 10432.png',
#  ' 10433.png',
#  ' 10434.png',
#  ' 10435.png',
#  ' 10436.png',
#  ' 10437.png',
#  ' 10438.png',
#  ' 10439.png',
#  ' 1044.png',
#  ' 10440.png',
#  ' 10441.png',
#  ' 10442.png',
#  ' 10443.png',
#  ' 10444.png',
#  ' 10445.png',
#  ' 10446.png',
#  ' 10447.png',
#  ' 10448.png',
#  ' 10449.png',
#  ' 1045.png',
#  ' 10450.png',
#  ' 10451.png',
#  ' 10452.png',
#  ' 10453.png',
#  ' 10454.png',
#  ' 10455.png',
#  ' 10456.png',
#  ' 10457.png',
#  ' 10458.png',
#  ' 10459.png',
#  ' 1046.png',
#  ' 10460.png',
#  ' 10461.png',
#  ' 10462.png',
#  ' 10463.png',
#  ' 10464.png',
#  ' 10465.png',
#  ' 10466.png',
#  ' 10467.png',
#  ' 10468.png',
#  ' 10469.png',
#  ' 1047.png',
#  ' 10470.png',
#  ' 10471.png',
#  ' 10472.png',
#  ' 10473.png',
#  ' 10474.png',
#  ' 10475.png',
#  ' 10476.png',
#  ' 10477.png',
#  ' 10478.png',
#  ' 10479.png',
#  ' 1048.png',
#  ' 10480.png',
#  ' 10481.png',
#  ' 10482.png',
#  ' 10483.png',
#  ' 10484.png',
#  ' 10485.png',
#  ' 10486.png',
#  ' 10487.png',
#  ' 10488.png',
#  ' 10489.png',
#  ' 1049.png',
#  ' 10490.png',
#  ' 10491.png',
#  ' 10492.png',
#  ' 10493.png',
#  ' 10494.png',
#  ' 10495.png',
#  ' 10496.png',
#  ' 10497.png',
#  ' 10498.png',
#  ' 10499.png',
#  ' 105.png',
#  ' 1050.png',
#  ' 10500.png',
#  ' 10501.png',
#  ' 10502.png',
#  ' 10503.png',
#  ' 10504.png',
#  ' 10505.png',
#  ' 10506.png',
#  ' 10507.png',
#  ' 10508.png',
#  ' 10509.png',
#  ' 1051.png',
#  ' 10510.png',
#  ' 10511.png',
#  ' 10512.png',
#  ' 10513.png',
#  ' 10514.png',
#  ' 10515.png',
#  ' 10516.png',
#  ' 10517.png',
#  ' 10518.png',
#  ' 10519.png',
#  ' 1052.png',
#  ' 10520.png',
#  ' 10521.png',
#  ' 10522.png',
#  ' 10523.png',
#  ' 10524.png',
#  ' 10525.png',
#  ' 10526.png',
#  ' 10527.png',
#  ' 10528.png',
#  ' 10529.png',
#  ' 1053.png',
#  ' 10530.png',
#  ' 10531.png',
#  ' 10532.png',
#  ' 10533.png',
#  ' 10534.png',
#  ' 10535.png',
#  ' 10536.png',
#  ' 10537.png',
#  ' 10538.png',
#  ' 10539.png',
#  ' 1054.png',
#  ' 10540.png',
#  ' 10541.png',
#  ' 10542.png',
#  ' 10543.png',
#  ' 10544.png',
#  ' 10545.png',
#  ' 10546.png',
#  ' 10547.png',
#  ' 10548.png',
#  ' 10549.png',
#  ' 1055.png',
#  ' 10550.png',
#  ' 10551.png',
#  ' 10552.png',
#  ' 10553.png',
#  ' 10554.png',
#  ' 10555.png',
#  ' 10556.png',
#  ' 10557.png',
#  ' 10558.png',
#  ' 10559.png',
#  ' 1056.png',
#  ' 10560.png',
#  ' 10561.png',
#  ' 10563.png',
#  ' 10564.png',
#  ' 10565.png',
#  ' 10566.png',
#  ' 10567.png',
#  ' 10568.png',
#  ' 10569.png',
#  ' 1057.png',
#  ' 10570.png',
#  ' 10571.png',
#  ' 10572.png',
#  ' 10573.png',
#  ' 10574.png',
#  ' 10575.png',
#  ' 10576.png',
#  ' 10577.png',
#  ' 10578.png',
#  ' 10579.png',
#  ' 1058.png',
#  ' 10580.png',
#  ' 10581.png',
#  ' 10582.png',
#  ' 10583.png',
#  ' 10584.png',
#  ' 10585.png',
#  ' 10586.png',
#  ' 10587.png',
#  ' 10588.png',
#  ' 10589.png',
#  ' 1059.png',
#  ' 10590.png',
#  ' 10591.png',
#  ' 10592.png',
#  ' 10593.png',
#  ' 10594.png',
#  ' 10596.png',
#  ' 10597.png',
#  ' 10598.png',
#  ' 10599.png',
#  ' 106.png',
#  ' 1060.png',
#  ' 10600.png',
#  ' 10601.png',
#  ' 10602.png',
#  ' 10603.png',
#  ' 10604.png',
#  ' 10605.png',
#  ' 10606.png',
#  ' 10607.png',
#  ' 10608.png',
#  ' 10609.png',
#  ' 1061.png',
#  ' 10610.png',
#  ' 10611.png',
#  ' 10612.png',
#  ' 10613.png',
#  ' 10614.png',
#  ' 10615.png',
#  ' 10616.png',
#  ' 10617.png',
#  ' 10618.png',
#  ' 10619.png',
#  ' 1062.png',
#  ' 10620.png',
#  ' 10621.png',
#  ' 10622.png',
#  ' 10623.png',
#  ' 10624.png',
#  ' 10625.png',
#  ' 10626.png',
#  ' 10627.png',
#  ' 10628.png',
#  ' 10629.png',
#  ' 1063.png',
#  ' 10630.png',
#  ' 10631.png',
#  ' 10632.png',
#  ' 10633.png',
#  ' 10634.png',
#  ' 10635.png',
#  ' 10636.png',
#  ' 10637.png',
#  ' 10638.png',
#  ' 10639.png',
#  ' 1064.png',
#  ' 10640.png',
#  ' 10641.png',
#  ' 10642.png',
#  ' 10643.png',
#  ' 10644.png',
#  ' 10645.png',
#  ' 10646.png',
#  ' 10647.png',
#  ' 10648.png',
#  ' 10649.png',
#  ' 1065.png',
#  ' 10650.png',
#  ' 10651.png',
#  ' 10652.png',
#  ' 10653.png',
#  ' 10654.png',
#  ' 10655.png',
#  ' 10656.png',
#  ' 10657.png',
#  ' 10658.png',
#  ' 10659.png',
#  ' 1066.png',
#  ' 10660.png',
#  ' 10661.png',
#  ' 10662.png',
#  ' 10663.png',
#  ' 10664.png',
#  ' 10665.png',
#  ' 10666.png',
#  ' 10667.png',
#  ' 10668.png',
#  ' 1067.png',
#  ' 10670.png',
#  ' 10671.png',
#  ' 10672.png',
#  ' 10673.png',
#  ' 10674.png',
#  ' 10675.png',
#  ' 10676.png',
#  ' 10677.png',
#  ' 10678.png',
#  ' 10679.png',
#  ' 1068.png',
#  ' 10680.png',
#  ' 10681.png',
#  ' 10682.png',
#  ' 10683.png',
#  ' 10684.png',
#  ' 10685.png',
#  ' 10686.png',
#  ' 10687.png',
#  ' 10688.png',
#  ' 10689.png',
#  ' 1069.png',
#  ' 10690.png',
#  ' 10691.png',
#  ' 10692.png',
#  ' 10693.png',
#  ' 10694.png',
#  ' 10695.png',
#  ' 10696.png',
#  ' 10697.png',
#  ' 10698.png',
#  ' 10699.png',
#  ' 107.png',
#  ' 1070.png',
#  ' 10700.png',
#  ' 10701.png',
#  ' 10702.png',
#  ' 10703.png',
#  ' 10704.png',
#  ' 10705.png',
#  ' 10706.png',
#  ' 10707.png',
#  ' 10708.png',
#  ' 10709.png',
#  ' 1071.png',
#  ' 10710.png',
#  ' 10711.png',
#  ' 10712.png',
#  ' 10713.png',
#  ' 10714.png',
#  ' 10715.png',
#  ' 10716.png',
#  ' 10717.png',
#  ' 10718.png',
#  ' 10719.png',
#  ' 1072.png',
#  ' 10720.png',
#  ' 10721.png',
#  ' 10722.png',
#  ' 10723.png',
#  ' 10725.png',
#  ' 10726.png',
#  ' 10727.png',
#  ' 10728.png',
#  ' 10729.png',
#  ' 1073.png',
#  ' 10730.png',
#  ' 10731.png',
#  ' 10732.png',
#  ' 10733.png',
#  ' 10734.png',
#  ' 10735.png',
#  ' 10736.png',
#  ' 10737.png',
#  ' 10738.png',
#  ' 10739.png',
#  ' 1074.png',
#  ' 10740.png',
#  ' 10741.png',
#  ' 10742.png',
#  ' 10743.png',
#  ' 10744.png',
#  ' 10745.png',
#  ' 10746.png',
#  ' 10747.png',
#  ' 10748.png',
#  ' 10749.png',
#  ' 1075.png',
#  ' 10750.png',
#  ' 10751.png',
#  ' 10752.png',
#  ' 10753.png',
#  ' 10754.png',
#  ' 10755.png',
#  ' 10756.png',
#  ' 10757.png',
#  ' 10758.png',
#  ' 10759.png',
#  ' 1076.png',
#  ' 10760.png',
#  ' 10761.png',
#  ' 10762.png',
#  ' 10763.png',
#  ' 10764.png',
#  ' 10765.png',
#  ' 10766.png',
#  ' 10767.png',
#  ' 10768.png',
#  ' 10769.png',
#  ' 1077.png',
#  ' 10770.png',
#  ' 10771.png',
#  ' 10772.png',
#  ' 10773.png',
#  ' 10774.png',
#  ' 10775.png',
#  ' 10776.png',
#  ' 10777.png',
#  ' 10778.png',
#  ' 10779.png',
#  ' 1078.png',
#  ' 10780.png',
#  ' 10781.png',
#  ' 10782.png',
#  ' 10783.png',
#  ' 10784.png',
#  ' 10785.png',
#  ' 10786.png',
#  ' 10787.png',
#  ' 10788.png',
#  ' 10789.png',
#  ' 1079.png',
#  ' 10790.png',
#  ' 10791.png',
#  ' 10792.png',
#  ' 10793.png',
#  ' 10794.png',
#  ' 10795.png',
#  ' 10796.png',
#  ' 10797.png',
#  ' 10798.png',
#  ' 10799.png',
#  ' 108.png',
#  ' 1080.png',
#  ' 10800.png',
#  ' 10801.png',
#  ' 10802.png',
#  ' 10803.png',
#  ' 10804.png',
#  ' 10805.png',
#  ' 10806.png',
#  ' 10807.png',
#  ' 10808.png',
#  ' 10809.png',
#  ' 1081.png',
#  ' 10810.png',
#  ' 10811.png',
#  ' 10812.png',
#  ' 10813.png',
#  ' 10814.png',
#  ' 10815.png',
#  ' 10816.png',
#  ' 10817.png',
#  ' 10818.png',
#  ' 10819.png',
#  ' 1082.png',
#  ' 10820.png',
#  ' 10821.png',
#  ' 10822.png',
#  ' 10823.png',
#  ' 10824.png',
#  ' 10825.png',
#  ' 10826.png',
#  ' 10827.png',
#  ' 10828.png',
#  ' 10829.png',
#  ' 1083.png',
#  ' 10830.png',
#  ' 10831.png',
#  ' 10832.png',
#  ' 10833.png',
#  ' 10834.png',
#  ' 10835.png',
#  ' 10836.png',
#  ' 10837.png',
#  ' 10838.png',
#  ' 10839.png',
#  ' 1084.png',
#  ' 10840.png',
#  ' 10841.png',
#  ' 10842.png',
#  ' 10843.png',
#  ' 10844.png',
#  ' 10845.png',
#  ' 10846.png',
#  ' 10847.png',
#  ' 10848.png',
#  ' 10849.png',
#  ' 1085.png',
#  ' 10850.png',
#  ' 10851.png',
#  ' 10852.png',
#  ' 10853.png',
#  ' 10854.png',
#  ' 10855.png',
#  ' 10856.png',
#  ' 10857.png',
#  ' 10858.png',
#  ' 10859.png',
#  ' 1086.png',
#  ' 10860.png',
#  ' 10861.png',
#  ' 10862.png',
#  ' 10863.png',
#  ' 10864.png',
#  ' 10865.png',
#  ' 10866.png',
#  ' 10867.png',
#  ' 10868.png',
#  ' 10869.png',
#  ' 1087.png',
#  ' 10870.png',
#  ' 10871.png',
#  ' 10872.png',
#  ' 10873.png',
#  ' 10874.png',
#  ' 10875.png',
#  ' 10876.png',
#  ' 10877.png',
#  ' 10878.png',
#  ' 10879.png',
#  ' 1088.png',
#  ' 10880.png',
#  ' 10881.png',
#  ' 10882.png',
#  ' 10883.png',
#  ' 10884.png',
#  ' 10885.png',
#  ' 10886.png',
#  ' 10887.png',
#  ' 10888.png',
#  ' 10889.png',
#  ' 1089.png',
#  ' 10890.png',
#  ' 10891.png',
#  ' 10892.png',
#  ' 10893.png',
#  ' 10894.png',
#  ' 10895.png',
#  ' 10896.png',
#  ' 10897.png',
#  ' 10898.png',
#  ' 10899.png',
#  ' 1090.png',
#  ' 10900.png',
#  ' 10901.png',
#  ' 10902.png',
#  ' 10903.png',
#  ' 10904.png',
#  ...]

# %%
import pandas as pd
df = pd.DataFrame()
df['filename'] = test_filenames
df['label'] = preds
df
# Out:
#          filename    label
# 0           1.png   enface
# 1          10.png   enface
# 2         100.png   enface
# 3        1000.png  profile
# 4       10000.png  profile
# ...           ...      ...
# 11509    9995.png  profile
# 11510    9996.png  profile
# 11511    9997.png   enface
# 11512    9998.png   enface
# 11513    9999.png  profile
#
# [11514 rows x 2 columns]

# %%
for i in range(len(df)):
    if df["label"][i] == "enface":
        df["label"][i] = 0
    else: 
        df["label"][i] =1
# df.to_csv(Path('./submission.csv'), index=False)

# %%
df
# Out:
#          filename label
# 0           1.png     0
# 1          10.png     0
# 2         100.png     0
# 3        1000.png     1
# 4       10000.png     1
# ...           ...   ...
# 11509    9995.png     1
# 11510    9996.png     1
# 11511    9997.png     0
# 11512    9998.png     0
# 11513    9999.png     1
#
# [11514 rows x 2 columns]

# %%
df["filename"][0]
# Out:
# ' 1.png'

# %%
for i in range(len(df)):
    df["filename"][i] = df["filename"][i].replace(" ","")
df
# Out:
#         filename label
# 0          1.png     0
# 1         10.png     0
# 2        100.png     0
# 3       1000.png     1
# 4      10000.png     1
# ...          ...   ...
# 11509   9995.png     1
# 11510   9996.png     1
# 11511   9997.png     0
# 11512   9998.png     0
# 11513   9999.png     1
#
# [11514 rows x 2 columns]

# %%
df["filename"][0]
# Out:
# '1.png'

# %%
df.to_csv(Path('./submission6.csv'), index=False)

# %%
sample_sub = pd.read_csv("sample_submission.csv")
sample_sub = sample_sub.drop("label", axis=1)
sample_sub
# Out:
#         filename
# 0          1.png
# 1          2.png
# 2          3.png
# 3          5.png
# 4          6.png
# ...          ...
# 11509  11578.png
# 11510  11579.png
# 11511  11580.png
# 11512  11581.png
# 11513  11582.png
#
# [11514 rows x 1 columns]

# %%
sample_sub['filename'][0]
# Out:
# '1.png'

# %%
pd.merge(df, sample_sub, on = "filename")
# Out:
# Empty DataFrame
# Columns: [filename, label]
# Index: []

# %%
for i in range(len(sample_sub)):
    for j in range(len(sample_sub)):
        if sample_sub["filename"][i] == df["filename"][j]:
            sample_sub["label"][i] = df["label"][j]

sample_sub
# Out:
#         filename  label
# 0          1.png      1
# 1          2.png      1
# 2          3.png      1
# 3          5.png      1
# 4          6.png      1
# ...          ...    ...
# 11509  11578.png      1
# 11510  11579.png      1
# 11511  11580.png      1
# 11512  11581.png      1
# 11513  11582.png      1
#
# [11514 rows x 2 columns]

# %%
sample_sub.to_csv(Path('./submission2.csv'), index=False)
